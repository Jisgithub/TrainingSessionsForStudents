# %% [markdown]
# <a href="https://colab.research.google.com/github/sudheepelayidom/TrainingSessionsForStudents/blob/main/MNIST_DisplayOnly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tensorflow matplotlib

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# Load the MNIST dataset
# The dataset is already split into training and testing sets
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# The MNIST dataset contains 70,000 images in total
# We will display the first 25 images
fig, axes = plt.subplots(5, 5, figsize=(8, 8),
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    # Display the image
    ax.imshow(x_train[i], cmap='gray')

    # Add the label as the title
    ax.set_title(f"Label: {y_train[i]}")

plt.tight_layout()
plt.show()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
